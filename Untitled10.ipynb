# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1AO5B7/WIDS-DATATHON-2021/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import keras
import tensorboard
import tensorflow as tf
import random as rd

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve,auc

# %%
data = pd.read_csv('/content/TrainingWiDS2021.csv')
data.head()
# Out:
#    Unnamed: 0  encounter_id  ...  solid_tumor_with_metastasis  diabetes_mellitus
# 0           1        214826  ...                            0                  1
# 1           2        246060  ...                            0                  1
# 2           3        276985  ...                            0                  0
# 3           4        262220  ...                            0                  0
# 4           5        201746  ...                            0                  0
#
# [5 rows x 181 columns]

# %%
data.shape
# Out:
# (130157, 181)

# %%
# Check for NaN under an entire DataFrame: 
data.isna().any()
# Out:
# Unnamed: 0                     False
# encounter_id                   False
# hospital_id                    False
# age                             True
# bmi                             True
#                                ...
# immunosuppression              False
# leukemia                       False
# lymphoma                       False
# solid_tumor_with_metastasis    False
# diabetes_mellitus              False
# Length: 181, dtype: bool

# %%
data.isna().sum()
# Out:
# Unnamed: 0                        0
# encounter_id                      0
# hospital_id                       0
# age                            4988
# bmi                            4490
#                                ...
# immunosuppression                 0
# leukemia                          0
# lymphoma                          0
# solid_tumor_with_metastasis       0
# diabetes_mellitus                 0
# Length: 181, dtype: int64

# %%
 # Count the NaN under an entire DataFrame:
data.isnull().sum().sum()
# Out:
# 8018193

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'encounter_id', 'hospital_id', 'age', 'bmi',
#        'elective_surgery', 'ethnicity', 'gender', 'height',
#        'hospital_admit_source',
#        ...
#        'h1_pao2fio2ratio_max', 'h1_pao2fio2ratio_min', 'aids', 'cirrhosis',
#        'hepatic_failure', 'immunosuppression', 'leukemia', 'lymphoma',
#        'solid_tumor_with_metastasis', 'diabetes_mellitus'],
#       dtype='object', length=181)

# %%
data.describe()
# Out:
#           Unnamed: 0  ...  diabetes_mellitus
# count  130157.000000  ...      130157.000000
# mean    65079.000000  ...           0.216285
# std     37573.233831  ...           0.411712
# min         1.000000  ...           0.000000
# 25%     32540.000000  ...           0.000000
# 50%     65079.000000  ...           0.000000
# 75%     97618.000000  ...           0.000000
# max    130157.000000  ...           1.000000
#
# [8 rows x 175 columns]

# %%
data.describe(include="all")
# Out:
#            Unnamed: 0  ...  diabetes_mellitus
# count   130157.000000  ...      130157.000000
# unique            NaN  ...                NaN
# top               NaN  ...                NaN
# freq              NaN  ...                NaN
# mean     65079.000000  ...           0.216285
# std      37573.233831  ...           0.411712
# min          1.000000  ...           0.000000
# 25%      32540.000000  ...           0.000000
# 50%      65079.000000  ...           0.000000
# 75%      97618.000000  ...           0.000000
# max     130157.000000  ...           1.000000
#
# [11 rows x 181 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130157 entries, 0 to 130156
# Columns: 181 entries, Unnamed: 0 to diabetes_mellitus
# dtypes: float64(157), int64(18), object(6)
# memory usage: 179.7+ MB

# %%
del data['ethnicity']
del data['hospital_admit_source']
del data['icu_admit_source']
del data['icu_stay_type']
del data['icu_type']

# %%
data.columns = data.columns.str.strip()

# %%
data['gender'] = data.gender.map(dict(M=1, F=0))

# %%
data = data.fillna(method="ffill")

# %%
data.isna().sum().sum()
# Out:
# 8162

# %%
data = data.fillna(method="bfill")

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
# Implementing the model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
x = data.loc[ : , data.columns != 'diabetes_mellitus']
y = data['diabetes_mellitus']

# %%
model = RandomForestRegressor()
model.fit(x,y)

# %%
df = pd.read_csv('/content/UnlabeledWiDS2021.csv')

# %%
df.head()

# %%
df.shape
# Out:
# (10234, 180)

# %%
del df['ethnicity']
del df['hospital_admit_source'] 
del df['icu_admit_source']
del df['icu_stay_type']
del df['icu_type']

# %%
df.columns = df.columns.str.strip()

# %%
df['gender'] = df.gender.map(dict(M=1, F=0))

# %%
df = df.fillna(method="ffill")

# %%
df.isna().sum().sum()
# Out:
# 1588

# %%
df = df.fillna(method="bfill")

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.drop(df.tail(795).index, 
        inplace = True)

# %%
y_pred = model.predict(df)
y_pred
# Out:
# array([0.33, 0.41, 0.32, ..., 0.25, 0.14, 0.37])

# %%
roc_auc_score(y,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-8c9a4825a035> in <module>()
# ----> 1 roc_auc_score(y,y_pred)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     388                                              max_fpr=max_fpr),
#     389                                      y_true, y_score, average,
# --> 390                                      sample_weight=sample_weight)
#     391     else:  # multilabel-indicator
#     392         return _average_binary_score(partial(_binary_roc_auc_score,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      75
#      76     if y_type == "binary":
# ---> 77         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78
#      79     check_consistent_length(y_true, y_score, sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     223
#     224     fpr, tpr, _ = roc_curve(y_true, y_score,
# --> 225                             sample_weight=sample_weight)
#     226     if max_fpr is None or max_fpr == 1:
#     227         return auc(fpr, tpr)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     769     """
#     770     fps, tps, thresholds = _binary_clf_curve(
# --> 771         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     772
#     773     # Attempt to drop thresholds corresponding to points in between and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     536         raise ValueError("{0} format is not supported".format(y_type))
#     537
# --> 538     check_consistent_length(y_true, y_score, sample_weight)
#     539     y_true = column_or_1d(y_true)
#     540     y_score = column_or_1d(y_score)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [130157, 9439]

# %%
output = pd.DataFrame({'encounter_id':df['encounter_id'],'diabetes_milletus':y_pred})
output
# Out:
#       encounter_id  diabetes_milletus
# 0           144740               0.33
# 1           141990               0.41
# 2           142038               0.32
# 3           138628               0.30
# 4           141682               0.37
# ...            ...                ...
# 9434        135424               0.37
# 9435        143540               0.20
# 9436        138804               0.25
# 9437        143701               0.14
# 9438        136209               0.37
#
# [9439 rows x 2 columns]
